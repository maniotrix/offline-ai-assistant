# %%
# add karna-python-backend to the path
import sys
sys.path.append('C:/Users/Prince/Documents/GitHub/Proejct-Karna/offline-ai-assistant/karna-python-backend')

from importlib import reload  # Not needed in Python 2
import logging
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%I:%M:%S')

logger = logging.getLogger(__name__)

# %%
from image_diff_creator_test import main
main()
# Out:
# 02:15:15 INFO:NumExpr defaulting to 12 threads.
# 02:15:19 INFO:Starting image diff test with JSON data
# 02:15:19 INFO:JSON path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshot_events_883c46f5-c62d-4799-baa1-5e3b12f12e8c.json
# 02:15:19 INFO:Loading screenshot events from JSON
# 02:15:19 INFO:Loading screenshot events from JSON file: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshot_events_883c46f5-c62d-4799-baa1-5e3b12f12e8c.json
# 02:15:19 INFO:Loaded 4 valid mouse events with screenshots
# 02:15:19 INFO:Generating OmniParser results
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Florence2LanguageForConditionalGeneration has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# 02:15:27 INFO:Parsing image path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131725_617204.png
# Omniparser initialized!!!
# image size: (1920, 1080)
#
# 0: 736x1280 94 icons, 69.3ms
# Speed: 8.1ms preprocess, 69.3ms inference, 50.0ms postprocess per image at shape (1, 3, 736, 1280)
# len(filtered_boxes): 101 38
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 02:15:30 INFO:Created omniparser result for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:15:30 INFO:Getting omniparser result model for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:15:30 INFO:Converting parsed content df to bounding boxes for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:15:30 INFO:Pre-processed parsed content results for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:15:30 INFO:Creating omniparser result model for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:15:30 INFO:Created omniparser result model for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:15:30 INFO:Parsing image path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131729_196616.png
# time to get parsed content: 0.7474093437194824
# image size: (1920, 1080)
#
# 0: 736x1280 90 icons, 67.0ms
# Speed: 11.7ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 736, 1280)
# len(filtered_boxes): 97 37
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 02:15:33 INFO:Created omniparser result for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:15:33 INFO:Getting omniparser result model for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:15:33 INFO:Converting parsed content df to bounding boxes for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:15:33 INFO:Pre-processed parsed content results for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:15:33 INFO:Creating omniparser result model for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:15:33 INFO:Created omniparser result model for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:15:33 INFO:Parsing image path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131757_316854.png
# time to get parsed content: 0.6559145450592041
# image size: (1920, 1080)
#
# 0: 736x1280 91 icons, 66.3ms
# Speed: 12.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 736, 1280)
# len(filtered_boxes): 100 36
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 02:15:35 INFO:Created omniparser result for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:15:35 INFO:Getting omniparser result model for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:15:35 INFO:Converting parsed content df to bounding boxes for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:15:35 INFO:Pre-processed parsed content results for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:15:35 INFO:Creating omniparser result model for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:15:35 INFO:Created omniparser result model for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:15:35 INFO:Parsing image path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131801_573080.png
# time to get parsed content: 0.6972012519836426
# image size: (1920, 1080)
#
# 0: 736x1280 91 icons, 66.3ms
# Speed: 19.7ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 736, 1280)
# len(filtered_boxes): 100 36
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 02:15:38 INFO:Created omniparser result for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:15:38 INFO:Getting omniparser result model for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:15:38 INFO:Converting parsed content df to bounding boxes for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:15:38 INFO:Pre-processed parsed content results for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:15:38 INFO:Creating omniparser result model for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:15:38 INFO:Created omniparser result model for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:15:38 INFO:Completed getting omniparser result models for 4 events
# 02:15:38 INFO:Using models from timestamps:
# 02:15:38 INFO:  Model 1: 2025-03-29 13:17:25.761291
# 02:15:38 INFO:  Model 2: 2025-03-29 13:17:29.333759
# 02:15:38 INFO:Image 1: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131725_617204.png
# 02:15:38 INFO:Image 2: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131729_196616.png
# 02:15:38 INFO:Initializing ImageDiffCreator
# 02:15:38 INFO:Source types filter: None
# 02:15:38 INFO:Saliency threshold: 0.05
# time to get parsed content: 0.7201268672943115
# 02:15:39 INFO:Running diff detection
# 02:15:42 INFO:Diff detection complete
# 02:15:42 INFO:
# ==================================================
# DIFF SUMMARY
# ==================================================
# Total changes detected: 12
# - Added elements: 1
# - Removed elements: 5
# - Text changes: 6
# - Visual changes: 0
# --------------------------------------------------
# ADDED ELEMENTS:
#   1. ID: 81, Type: icon, Content: 'High'
#      Saliency: 0.245, Bbox: [593.0, 501.0, 627.0, 530.0]
# REMOVED ELEMENTS:
#   1. ID: 99, Type: icon, Content: 'Superscript'
#      Saliency: 0.265, Bbox: [1091.0, 431.0, 1103.0, 449.0]
#   2. ID: 100, Type: icon, Content: 'Add'
#      Saliency: 0.153, Bbox: [757.0, 9.0, 779.0, 31.0]
#   3. ID: 10, Type: text, Content: 'AAsk anything'
#      Saliency: 0.252, Bbox: [596.0, 500.0, 698.0, 528.0]
#   4. ID: 81, Type: icon, Content: 'M0,0L9,0 4.5,5z'
#      Saliency: 0.120, Bbox: [1643.0, 1044.0, 1663.0, 1074.0]
#   5. ID: 85, Type: icon, Content: 'Oval'
#      Saliency: 0.118, Bbox: [1667.0, 1043.0, 1687.0, 1075.0]
# TEXT CHANGES:
#   1. ID: 38, Type: icon
#      Old text: 'Up arrow'
#      New text: 'Up or down.'
#      Similarity: 0.545, Saliency: 0.245
#   2. ID: 68, Type: icon
#      Old text: 'Image'
#      New text: 'Home'
#      Similarity: 0.200, Saliency: 0.136
#   3. ID: 75, Type: icon
#      Old text: 'Currencyurrency'
#      New text: 'Currency'
#      Similarity: 0.533, Saliency: 0.157
#   4. ID: 79, Type: icon
#      Old text: 'Play'
#      New text: 'Play video'
#      Similarity: 0.400, Saliency: 0.175
#   5. ID: 82, Type: icon
#      Old text: 'Mail'
#      New text: 'Movies & TV'
#      Similarity: 0.182, Saliency: 0.143
#   6. ID: 88, Type: icon
#      Old text: '34, September, 2024'
#      New text: 'Minimize'
#      Similarity: 0.053, Saliency: 0.116
# ==================================================
# 02:15:42 INFO:Creating visualizations
# ==================================================
# DIFF SUMMARY
# ==================================================
# Total changes detected: 12
# - Added elements: 1
# - Removed elements: 5
# - Text changes: 6
# - Visual changes: 0
# --------------------------------------------------
# ADDED ELEMENTS:
#   1. ID: 81, Type: icon, Content: 'High'
#      Saliency: 0.245, Bbox: [593.0, 501.0, 627.0, 530.0]
# REMOVED ELEMENTS:
#   1. ID: 99, Type: icon, Content: 'Superscript'
#      Saliency: 0.265, Bbox: [1091.0, 431.0, 1103.0, 449.0]
#   2. ID: 100, Type: icon, Content: 'Add'
#      Saliency: 0.153, Bbox: [757.0, 9.0, 779.0, 31.0]
#   3. ID: 10, Type: text, Content: 'AAsk anything'
#      Saliency: 0.252, Bbox: [596.0, 500.0, 698.0, 528.0]
#   4. ID: 81, Type: icon, Content: 'M0,0L9,0 4.5,5z'
#      Saliency: 0.120, Bbox: [1643.0, 1044.0, 1663.0, 1074.0]
#   5. ID: 85, Type: icon, Content: 'Oval'
#      Saliency: 0.118, Bbox: [1667.0, 1043.0, 1687.0, 1075.0]
# TEXT CHANGES:
#   1. ID: 38, Type: icon
#      Old text: 'Up arrow'
#      New text: 'Up or down.'
#      Similarity: 0.545, Saliency: 0.245
#   2. ID: 68, Type: icon
#      Old text: 'Image'
#      New text: 'Home'
#      Similarity: 0.200, Saliency: 0.136
#   3. ID: 75, Type: icon
#      Old text: 'Currencyurrency'
#      New text: 'Currency'
#      Similarity: 0.533, Saliency: 0.157
#   4. ID: 79, Type: icon
#      Old text: 'Play'
#      New text: 'Play video'
#      Similarity: 0.400, Saliency: 0.175
#   5. ID: 82, Type: icon
#      Old text: 'Mail'
#      New text: 'Movies & TV'
#      Similarity: 0.182, Saliency: 0.143
#   6. ID: 88, Type: icon
#      Old text: '34, September, 2024'
#      New text: 'Minimize'
#      Similarity: 0.053, Saliency: 0.116
# ==================================================
# 02:15:44 INFO:Saved visualization to c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\karna-python-backend\inference\omniparser\diff_output\diff_visualization_1743669943.png
# 02:15:44 INFO:Visualization saved to c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\karna-python-backend\inference\omniparser\diff_output
