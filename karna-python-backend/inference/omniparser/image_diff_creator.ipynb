# %%
# add karna-python-backend to the path
import sys
sys.path.append('C:/Users/Prince/Documents/GitHub/Proejct-Karna/offline-ai-assistant/karna-python-backend')

from importlib import reload  # Not needed in Python 2
import logging
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%I:%M:%S')

logger = logging.getLogger(__name__)

# %%
from image_diff_creator_test import main
main()
# Out:
# 02:32:46 INFO:NumExpr defaulting to 12 threads.
# 02:32:50 INFO:Starting image diff test with JSON data
# 02:32:50 INFO:JSON path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshot_events_883c46f5-c62d-4799-baa1-5e3b12f12e8c.json
# 02:32:50 INFO:Loading screenshot events from JSON
# 02:32:50 INFO:Loading screenshot events from JSON file: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshot_events_883c46f5-c62d-4799-baa1-5e3b12f12e8c.json
# 02:32:50 INFO:Loaded 4 valid mouse events with screenshots
# 02:32:50 INFO:Generating OmniParser results
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Florence2LanguageForConditionalGeneration has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# 02:32:58 INFO:Parsing image path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131725_617204.png
# Omniparser initialized!!!
# image size: (1920, 1080)
#
# 0: 736x1280 94 icons, 69.5ms
# Speed: 15.6ms preprocess, 69.5ms inference, 78.1ms postprocess per image at shape (1, 3, 736, 1280)
# len(filtered_boxes): 101 38
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 02:33:01 INFO:Created omniparser result for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:33:01 INFO:Getting omniparser result model for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:33:01 INFO:Converting parsed content df to bounding boxes for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:33:01 INFO:Pre-processed parsed content results for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:33:01 INFO:Creating omniparser result model for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:33:01 INFO:Created omniparser result model for event_id: 9b073de5-e2c1-468f-a1ce-b7d033d4be7b
# 02:33:01 INFO:Parsing image path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131729_196616.png
# time to get parsed content: 0.7689204216003418
# image size: (1920, 1080)
#
# 0: 736x1280 90 icons, 75.1ms
# Speed: 0.0ms preprocess, 75.1ms inference, 0.0ms postprocess per image at shape (1, 3, 736, 1280)
# len(filtered_boxes): 97 37
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 02:33:04 INFO:Created omniparser result for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:33:04 INFO:Getting omniparser result model for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:33:04 INFO:Converting parsed content df to bounding boxes for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:33:04 INFO:Pre-processed parsed content results for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:33:04 INFO:Creating omniparser result model for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:33:04 INFO:Created omniparser result model for event_id: 2065c037-ad71-41ff-b4b7-72ad3cfbc481
# 02:33:04 INFO:Parsing image path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131757_316854.png
# time to get parsed content: 0.670386791229248
# image size: (1920, 1080)
#
# 0: 736x1280 91 icons, 75.9ms
# Speed: 20.9ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 736, 1280)
# len(filtered_boxes): 100 36
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 02:33:06 INFO:Created omniparser result for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:33:06 INFO:Getting omniparser result model for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:33:06 INFO:Converting parsed content df to bounding boxes for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:33:06 INFO:Pre-processed parsed content results for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:33:06 INFO:Creating omniparser result model for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:33:06 INFO:Created omniparser result model for event_id: bf685989-b84d-40ba-8287-5770a19a5f0c
# 02:33:06 INFO:Parsing image path: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131801_573080.png
# time to get parsed content: 0.7129402160644531
# image size: (1920, 1080)
#
# 0: 736x1280 91 icons, 61.7ms
# Speed: 20.4ms preprocess, 61.7ms inference, 15.7ms postprocess per image at shape (1, 3, 736, 1280)
# len(filtered_boxes): 100 36
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 02:33:09 INFO:Created omniparser result for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:33:09 INFO:Getting omniparser result model for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:33:09 INFO:Converting parsed content df to bounding boxes for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:33:09 INFO:Pre-processed parsed content results for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:33:09 INFO:Creating omniparser result model for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:33:09 INFO:Created omniparser result model for event_id: 2d269a28-6aac-4484-84e7-18e7cf719987
# 02:33:09 INFO:Completed getting omniparser result models for 4 events
# 02:33:09 INFO:Using models from timestamps:
# 02:33:09 INFO:  Model 1: 2025-03-29 13:17:25.761291
# 02:33:09 INFO:  Model 2: 2025-03-29 13:17:29.333759
# 02:33:09 INFO:Image 1: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131725_617204.png
# 02:33:09 INFO:Image 2: C:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\data\chatgpt\883c46f5-c62d-4799-baa1-5e3b12f12e8c\screenshots\raw\screenshot_20250329_131729_196616.png
# 02:33:09 INFO:Initializing ImageDiffCreator
# 02:33:09 INFO:Source types filter: None
# 02:33:09 INFO:Saliency threshold: 0.05
# time to get parsed content: 0.7157130241394043
# 02:33:09 INFO:Running diff detection
# 02:33:13 INFO:Diff detection complete
# 02:33:13 INFO:
# ==================================================
# DIFF SUMMARY
# ==================================================
# Total changes detected: 8
# - Added elements: 1
# - Removed elements: 5
# - Text changes: 0
# - Visual changes: 2
# --------------------------------------------------
# ADDED ELEMENTS:
#   1. ID: 81, Type: icon, Content: 'High'
#      Saliency: 0.245, Bbox: [593.0, 501.0, 627.0, 530.0]
# REMOVED ELEMENTS:
#   1. ID: 99, Type: icon, Content: 'Superscript'
#      Saliency: 0.265, Bbox: [1091.0, 431.0, 1103.0, 449.0]
#   2. ID: 100, Type: icon, Content: 'Add'
#      Saliency: 0.153, Bbox: [757.0, 9.0, 779.0, 31.0]
#   3. ID: 10, Type: text, Content: 'AAsk anything'
#      Saliency: 0.252, Bbox: [596.0, 500.0, 698.0, 528.0]
#   4. ID: 81, Type: icon, Content: 'M0,0L9,0 4.5,5z'
#      Saliency: 0.120, Bbox: [1643.0, 1044.0, 1663.0, 1074.0]
#   5. ID: 85, Type: icon, Content: 'Oval'
#      Saliency: 0.118, Bbox: [1667.0, 1043.0, 1687.0, 1075.0]
# VISUAL CHANGES:
#   1. ID: 38, Type: icon
#      Classification: identical
#      Similarity: 0.960, Diff ratio: 0.812
#      Saliency: 0.245
#   2. ID: 88, Type: icon
#      Classification: similar
#      Similarity: 0.847, Diff ratio: 0.249
#      Saliency: 0.116
# ==================================================
# 02:33:13 INFO:Creating visualizations
# ==================================================
# DIFF SUMMARY
# ==================================================
# Total changes detected: 8
# - Added elements: 1
# - Removed elements: 5
# - Text changes: 0
# - Visual changes: 2
# --------------------------------------------------
# ADDED ELEMENTS:
#   1. ID: 81, Type: icon, Content: 'High'
#      Saliency: 0.245, Bbox: [593.0, 501.0, 627.0, 530.0]
# REMOVED ELEMENTS:
#   1. ID: 99, Type: icon, Content: 'Superscript'
#      Saliency: 0.265, Bbox: [1091.0, 431.0, 1103.0, 449.0]
#   2. ID: 100, Type: icon, Content: 'Add'
#      Saliency: 0.153, Bbox: [757.0, 9.0, 779.0, 31.0]
#   3. ID: 10, Type: text, Content: 'AAsk anything'
#      Saliency: 0.252, Bbox: [596.0, 500.0, 698.0, 528.0]
#   4. ID: 81, Type: icon, Content: 'M0,0L9,0 4.5,5z'
#      Saliency: 0.120, Bbox: [1643.0, 1044.0, 1663.0, 1074.0]
#   5. ID: 85, Type: icon, Content: 'Oval'
#      Saliency: 0.118, Bbox: [1667.0, 1043.0, 1687.0, 1075.0]
# VISUAL CHANGES:
#   1. ID: 38, Type: icon
#      Classification: identical
#      Similarity: 0.960, Diff ratio: 0.812
#      Saliency: 0.245
#   2. ID: 88, Type: icon
#      Classification: similar
#      Similarity: 0.847, Diff ratio: 0.249
#      Saliency: 0.116
# ==================================================
# 02:33:15 INFO:Saved visualization to c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\karna-python-backend\inference\omniparser\diff_output\diff_visualization_1743670994.png
# 02:33:15 INFO:Visualization saved to c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\karna-python-backend\inference\omniparser\diff_output
