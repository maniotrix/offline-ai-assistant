# %%
#  add karna-python-backend to the path
import sys
sys.path.append('C:/Users/Prince/Documents/GitHub/Proejct-Karna/offline-ai-assistant/karna-python-backend')
sys.path.append('C:/Users/Prince/Documents/GitHub/Proejct-Karna/offline-ai-assistant/karna-python-backend/inference')

from importlib import reload  # Not needed in Python 2
import logging
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%I:%M:%S')

logger = logging.getLogger(__name__)

from clustering import *
from config.paths import workspace_dir, backend_inference_dir
from inference.cortex_vision.omni_helper import OmniParserResultModel
# Out:
# 08:35:02 INFO:NumExpr defaulting to 12 threads.

# %%
import base64
import matplotlib.pyplot as plt
import io
from PIL import Image
def plot_base64_image(base64_image: str):
    plt.figure(figsize=(15,15))

    image = Image.open(io.BytesIO(base64.b64decode(base64_image)))
    plt.axis('off')

    plt.imshow(image)
    
def plot_numpy_image(np_image: np.ndarray):
    plt.figure(figsize=(15,15))
    plt.axis('off')
    plt.imshow(np_image)
    
# search id from parsed_content_results
def search_id_from_parsed_content_results(id: int, 
                                        result: OmniParserResultModel,
                                        interactive: bool = True):
    for i, item in enumerate(result.parsed_content_results):
        # print(f"Checking item {i}: id={item.id}, interactivity={item.interactivity}")
        # print(type(item.id))
        if item.id == id and item.interactivity == interactive:
            print(f"Found matching item: {item}")
            return item
    print("No matching item found")
    return None

# %%
# get omniparser result from image path
import os
from inference.cortex_vision.omni_helper import get_omniparser_inference_data_from_image_path
# get current directory
omniparser_dir = os.path.join(backend_inference_dir, "omniparser")
image_names = ["cluster_test.png", "test.png", "youtube_test.png", "cluster_tes2.png", "cluster_test3.png"]
image_path = os.path.join(omniparser_dir, image_names[2])
omniparser_result_model : OmniParserResultModel = get_omniparser_inference_data_from_image_path(image_path)
# Out:
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Omniparser initialized!!!
# image size: (1917, 873)
#
# 0: 608x1280 55 icons, 63.6ms
# Speed: 10.0ms preprocess, 63.6ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 1280)
# len(filtered_boxes): 72 58
# c:\Users\Prince\Documents\GitHub\Proejct-Karna\offline-ai-assistant\venv\lib\site-packages\transformers\generation\configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# time to get parsed content: 0.30391740798950195
# 09:08:34 INFO:Getting omniparser result model for event_id: -1
# 09:08:34 INFO:Converting parsed content df to bounding boxes for event_id: -1
# 09:08:34 INFO:Creating omniparser result model for event_id: -1
# 09:08:34 INFO:Created omniparser result model for event_id: -1

# %%
plot_base64_image(omniparser_result_model.omniparser_result.dino_labled_img)

# %%
search_id_from_parsed_content_results(60, omniparser_result_model, True)
# Out:
# Found matching item: ParsedContentResult(type='icon', bbox=[0.6876838207244873, 0.0035178791731595993, 0.7153934240341187, 0.06881023198366165], interactivity=True, content='Mic', source='box_yolo_content_yolo', id=60)
# ParsedContentResult(type='icon', bbox=[0.6876838207244873, 0.0035178791731595993, 0.7153934240341187, 0.06881023198366165], interactivity=True, content='Mic', source='box_yolo_content_yolo', id=60)

# %%
# create cluster preprocessor
parsed_content_results : List[ParsedContentResult] = omniparser_result_model.parsed_content_results
parsed_content_results
# Out:
# [ParsedContentResult(type='text', bbox=[0.7224830389022827, 0.3333333432674408, 0.9666144847869873, 0.3699885308742523], interactivity=False, content='1 N T E R $ T E L L A R', source='box_ocr_content_ocr', id=0),
#  ParsedContentResult(type='text', bbox=[0.8095983266830444, 0.4536082446575165, 0.8711528182029724, 0.4810996651649475], interactivity=False, content='11.07.2014', source='box_ocr_content_ocr', id=1),
#  ParsedContentResult(type='text', bbox=[0.17057903110980988, 0.5280641317367554, 0.19040167331695557, 0.550973653793335], interactivity=False, content='Mix', source='box_ocr_content_ocr', id=2),
#  ParsedContentResult(type='text', bbox=[0.1956181526184082, 0.5280641317367554, 0.24778299033641815, 0.550973653793335], interactivity=False, content='NNX LXSY', source='box_ocr_content_ocr', id=3),
#  ParsedContentResult(type='text', bbox=[0.25247782468795776, 0.5246277451515198, 0.3109024465084076, 0.5521191358566284], interactivity=False, content='HEMENESY', source='box_ocr_content_ocr', id=4),
#  ParsedContentResult(type='text', bbox=[0.7130934000015259, 0.5280641317367554, 0.732915997505188, 0.550973653793335], interactivity=False, content='Mix', source='box_ocr_content_ocr', id=5),
#  ParsedContentResult(type='text', bbox=[0.7365675568580627, 0.5246277451515198, 0.852373480796814, 0.5521191358566284], interactivity=False, content='Interstellar Main Theme', source='box_ocr_content_ocr', id=6),
#  ParsedContentResult(type='text', bbox=[0.8575899600982666, 0.5246277451515198, 0.9306207895278931, 0.5521191358566284], interactivity=False, content='Extra Extended', source='box_ocr_content_ocr', id=7),
#  ParsedContentResult(type='text', bbox=[0.17005738615989685, 0.5589919686317444, 0.36828377842903137, 0.5864834189414978], interactivity=False, content='NNX LXSY; Best Phonk Music; ROUDS; and more', source='box_ocr_content_ocr', id=8),
#  ParsedContentResult(type='text', bbox=[0.7115284204483032, 0.5567010045051575, 0.8502869009971619, 0.5864834189414978], interactivity=False, content='Soundtrack by Hans Zimmer', source='box_ocr_content_ocr', id=9),
#  ParsedContentResult(type='text', bbox=[0.1690140813589096, 0.5910652875900269, 0.23265519738197327, 0.6185566782951355], interactivity=False, content='Updated today', source='box_ocr_content_ocr', id=10),
#  ParsedContentResult(type='text', bbox=[0.47209182381629944, 0.6013745665550232, 0.541992723941803, 0.6242840886116028], interactivity=False, content='Shark Tank India', source='box_ocr_content_ocr', id=11),
#  ParsedContentResult(type='text', bbox=[0.7115284204483032, 0.5887743234634399, 0.9212310910224915, 0.619702160358429], interactivity=False, content='Hans Zimmer; Elton John; The Lyndhurst Orchestra,', source='box_ocr_content_ocr', id=12),
#  ParsedContentResult(type='text', bbox=[0.938445508480072, 0.5945017337799072, 0.9624413251876831, 0.6151202917098999], interactivity=False, content='more', source='box_ocr_content_ocr', id=13),
#  ParsedContentResult(type='text', bbox=[0.4715701639652252, 0.6277204751968384, 0.5174752473831177, 0.6552119255065918], interactivity=False, content='9OK views', source='box_ocr_content_ocr', id=14),
#  ParsedContentResult(type='text', bbox=[0.5216484069824219, 0.6277204751968384, 0.5779864192008972, 0.6575028896331787], interactivity=False, content='20 hours ago', source='box_ocr_content_ocr', id=15),
#  ParsedContentResult(type='text', bbox=[0.7115284204483032, 0.6231386065483093, 0.7741262316703796, 0.650629997253418], interactivity=False, content='Updated today', source='box_ocr_content_ocr', id=16),
#  ParsedContentResult(type='text', bbox=[0.7157016396522522, 0.70561283826828, 0.9728742837905884, 0.7548682689666748], interactivity=False, content='TRUMP MEETS WITH MODI', source='box_ocr_content_ocr', id=17),
#  ParsedContentResult(type='text', bbox=[0.7162232398986816, 0.9564719200134277, 0.7350026369094849, 0.9747995138168335], interactivity=False, content='LIVE', source='box_ocr_content_ocr', id=18),
#  ParsedContentResult(type='text', bbox=[0.9457485675811768, 0.9885452389717102, 0.9666144847869873, 1.0], interactivity=False, content='407', source='box_ocr_content_ocr', id=19),
#  ParsedContentResult(type='text', bbox=[0.9191445112228394, 0.5933562517166138, 0.9389671087265015, 0.6139748096466064], interactivity=False, content='and', source='box_ocr_content_ocr', id=20),
#  ParsedContentResult(type='icon', bbox=[0.43934792280197144, 0.1907311975955963, 0.7059518694877625, 0.519179105758667], interactivity=True, content='SHARL TANK INDMA SEASON3 17.50 ', source='box_yolo_content_ocr', id=21),
#  ParsedContentResult(type='icon', bbox=[0.00538606708869338, 0.09256456047296524, 0.1415003538131714, 0.15181049704551697], interactivity=True, content='Home ', source='box_yolo_content_ocr', id=22),
#  ParsedContentResult(type='icon', bbox=[0.36849552392959595, 0.09288273751735687, 0.41865384578704834, 0.14175133407115936], interactivity=True, content='Gaming ', source='box_yolo_content_ocr', id=23),
#  ParsedContentResult(type='icon', bbox=[0.6907647848129272, 0.09267636388540268, 0.7421563863754272, 0.14193828403949738], interactivity=True, content='TSeries ', source='box_yolo_content_ocr', id=24),
#  ParsedContentResult(type='icon', bbox=[0.6327955722808838, 0.09269450604915619, 0.6858711838722229, 0.14188160002231598], interactivity=True, content='Playlists ', source='box_yolo_content_ocr', id=25),
#  ParsedContentResult(type='icon', bbox=[0.32095158100128174, 0.09280528128147125, 0.3634975552558899, 0.1413000524044037], interactivity=True, content='Mixes ', source='box_yolo_content_ocr', id=26),
#  ParsedContentResult(type='icon', bbox=[0.42332568764686584, 0.09283379465341568, 0.48105213046073914, 0.14170069992542267], interactivity=True, content='Podcasts ', source='box_yolo_content_ocr', id=27),
#  ParsedContentResult(type='icon', bbox=[0.005902350414544344, 0.15065090358257294, 0.1444539725780487, 0.20890933275222778], interactivity=True, content='Shorts ', source='box_yolo_content_ocr', id=28),
#  ParsedContentResult(type='icon', bbox=[0.4850049316883087, 0.0926039069890976, 0.5597901940345764, 0.14160363376140594], interactivity=True, content='Hans Zimmer ', source='box_yolo_content_ocr', id=29),
#  ParsedContentResult(type='icon', bbox=[0.005245352163910866, 0.5867599844932556, 0.14888301491737366, 0.6455935835838318], interactivity=True, content='Watch later ', source='box_yolo_content_ocr', id=30),
#  ParsedContentResult(type='icon', bbox=[0.20395427942276, 0.09254961460828781, 0.24710732698440552, 0.14188125729560852], interactivity=True, content='Music ', source='box_yolo_content_ocr', id=31),
#  ParsedContentResult(type='icon', bbox=[0.0055572036653757095, 0.20743733644485474, 0.14661020040512085, 0.2667277157306671], interactivity=True, content='Subscriptions ', source='box_yolo_content_ocr', id=32),
#  ParsedContentResult(type='icon', bbox=[0.004837548825889826, 0.5296927690505981, 0.14902228116989136, 0.5884807109832764], interactivity=True, content='Your videos ', source='box_yolo_content_ocr', id=33),
#  ParsedContentResult(type='icon', bbox=[0.005619097501039505, 0.4135964512825012, 0.14942558109760284, 0.47476688027381897], interactivity=True, content='History ', source='box_yolo_content_ocr', id=34),
#  ParsedContentResult(type='icon', bbox=[0.005256724543869495, 0.47247084975242615, 0.14962969720363617, 0.5313931107521057], interactivity=True, content='Playlists ', source='box_yolo_content_ocr', id=35),
#  ParsedContentResult(type='icon', bbox=[0.005796647630631924, 0.26499083638191223, 0.14860782027244568, 0.3250972628593445], interactivity=True, content='YouTube Music ', source='box_yolo_content_ocr', id=36),
#  ParsedContentResult(type='icon', bbox=[0.005808723159134388, 0.6442058682441711, 0.1492740660905838, 0.7022632360458374], interactivity=True, content='Liked videos ', source='box_yolo_content_ocr', id=37),
#  ParsedContentResult(type='icon', bbox=[0.8387308120727539, 0.00867519062012434, 0.9053658843040466, 0.06442593783140182], interactivity=True, content='Create ', source='box_yolo_content_ocr', id=38),
#  ParsedContentResult(type='icon', bbox=[0.5644421577453613, 0.09269973635673523, 0.6280083656311035, 0.1417515128850937], interactivity=True, content='Web series ', source='box_yolo_content_ocr', id=39),
#  ParsedContentResult(type='icon', bbox=[0.7469134330749512, 0.09247610718011856, 0.8276195526123047, 0.1416824758052826], interactivity=True, content='Valentines Day ', source='box_yolo_content_ocr', id=40),
#  ParsedContentResult(type='icon', bbox=[0.2518804669380188, 0.09277400374412537, 0.3160809874534607, 0.1415386199951172], interactivity=True, content='Shark Tank ', source='box_yolo_content_ocr', id=41),
#  ParsedContentResult(type='icon', bbox=[0.28162887692451477, 0.002199941547587514, 0.6500113606452942, 0.06894425302743912], interactivity=True, content='Search ', source='box_yolo_content_ocr', id=42),
#  ParsedContentResult(type='icon', bbox=[0.007443118374794722, 0.7010635733604431, 0.14902736246585846, 0.758578896522522], interactivity=True, content='Downloads ', source='box_yolo_content_ocr', id=43),
#  ParsedContentResult(type='icon', bbox=[0.17016027867794037, 0.09251629561185837, 0.1985597461462021, 0.14142781496047974], interactivity=True, content='AlI ', source='box_yolo_content_ocr', id=44),
#  ParsedContentResult(type='icon', bbox=[0.010441840626299381, 0.8442457914352417, 0.14703981578350067, 0.8953403234481812], interactivity=True, content="90's Gaane ", source='box_yolo_content_ocr', id=45),
#  ParsedContentResult(type='icon', bbox=[0.01074366644024849, 0.9585211873054504, 0.14198309183120728, 1.0], interactivity=True, content='SHAANDAR GA_ ', source='box_yolo_content_ocr', id=46),
#  ParsedContentResult(type='icon', bbox=[0.8319765329360962, 0.09255202114582062, 0.9306425452232361, 0.1416061967611313], interactivity=True, content='Pritam Chakraborty ', source='box_yolo_content_ocr', id=47),
#  ParsedContentResult(type='icon', bbox=[0.44158098101615906, 0.531460165977478, 0.4669054448604584, 0.5846976637840271], interactivity=True, content='INdIA ', source='box_yolo_content_ocr', id=48),
#  ParsedContentResult(type='icon', bbox=[0.00978467520326376, 0.9016848802566528, 0.14278198778629303, 0.9527603387832642], interactivity=True, content='Firstpost ', source='box_yolo_content_ocr', id=49),
#  ParsedContentResult(type='icon', bbox=[0.005181372165679932, 0.35570552945137024, 0.14989276230335236, 0.41683074831962585], interactivity=True, content='You ', source='box_yolo_content_ocr', id=50),
#  ParsedContentResult(type='icon', bbox=[0.008656145073473454, 0.7909711599349976, 0.14954425394535065, 0.8445387482643127], interactivity=True, content='Subscriptions ', source='box_yolo_content_ocr', id=51),
#  ParsedContentResult(type='icon', bbox=[0.1703818291425705, 0.7006334066390991, 0.43480226397514343, 1.0], interactivity=True, content='Jhttlecrdvude 2154 tamintvaeo LIVE FOI7T7ot ', source='box_yolo_content_ocr', id=52),
#  ParsedContentResult(type='icon', bbox=[0.04444869980216026, 0.01584753580391407, 0.11976828426122665, 0.05579964816570282], interactivity=True, content='Premium ', source='box_yolo_content_ocr', id=53),
#  ParsedContentResult(type='icon', bbox=[0.4720156788825989, 0.560261070728302, 0.69294273853302, 0.593759298324585], interactivity=True, content='choice- No Plastic, Only Tastel New Sharks ', source='box_yolo_content_ocr', id=54),
#  ParsedContentResult(type='icon', bbox=[0.943854570388794, 0.48116612434387207, 0.9698492884635925, 0.502657949924469], interactivity=True, content='Mix ', source='box_yolo_content_ocr', id=55),
#  ParsedContentResult(type='icon', bbox=[0.46533817052841187, 0.5274810194969177, 0.7011525630950928, 0.5599376559257507], interactivity=True, content="'Gud Gum' Chewing Gum &1 smart ", source='box_yolo_content_ocr', id=56),
#  ParsedContentResult(type='icon', bbox=[0.4008517563343048, 0.4801653325557709, 0.42755618691444397, 0.5032917261123657], interactivity=True, content='Mix ', source='box_yolo_content_ocr', id=57),
#  ParsedContentResult(type='icon', bbox=[0.9105856418609619, 0.006418853998184204, 0.9386034607887268, 0.06425388902425766], interactivity=True, content='Notifications', source='box_yolo_content_yolo', id=58),
#  ParsedContentResult(type='icon', bbox=[0.9474241733551025, 0.010906282812356949, 0.9718462824821472, 0.061297185719013214], interactivity=True, content='NTVKAD - TVKAD', source='box_yolo_content_yolo', id=59),
#  ParsedContentResult(type='icon', bbox=[0.6876838207244873, 0.0035178791731595993, 0.7153934240341187, 0.06881023198366165], interactivity=True, content='Mic', source='box_yolo_content_yolo', id=60),
#  ParsedContentResult(type='icon', bbox=[0.6355438828468323, 0.006544807460159063, 0.6763216257095337, 0.06673665344715118], interactivity=True, content='Search', source='box_yolo_content_yolo', id=61),
#  ParsedContentResult(type='icon', bbox=[0.9572604894638062, 0.0899757444858551, 0.984149158000946, 0.1485850065946579], interactivity=True, content='HideHideHide', source='box_yolo_content_yolo', id=62),
#  ParsedContentResult(type='icon', bbox=[0.010925483889877796, 0.01156062912195921, 0.033255670219659805, 0.06228470802307129], interactivity=True, content='All Sheets', source='box_yolo_content_yolo', id=63),
#  ParsedContentResult(type='icon', bbox=[0.9592251181602478, 0.5200935006141663, 0.9762104749679565, 0.5652902722358704], interactivity=True, content='More options', source='box_yolo_content_yolo', id=64),
#  ParsedContentResult(type='icon', bbox=[0.9343668818473816, 0.09161408990621567, 0.9528475403785706, 0.14435815811157227], interactivity=True, content='Minimize', source='box_yolo_content_yolo', id=65),
#  ParsedContentResult(type='icon', bbox=[0.6884438991546631, 0.5270845890045166, 0.7044623494148254, 0.5726160407066345], interactivity=True, content='More options', source='box_yolo_content_yolo', id=66),
#  ParsedContentResult(type='icon', bbox=[0.42022421956062317, 0.5276275873184204, 0.4336584508419037, 0.5604800581932068], interactivity=True, content='More options', source='box_yolo_content_yolo', id=67),
#  ParsedContentResult(type='icon', bbox=[0.44100865721702576, 0.7013156414031982, 0.705618679523468, 1.0], interactivity=True, content='A painting or painting tool.', source='box_yolo_content_yolo', id=68),
#  ParsedContentResult(type='icon', bbox=[0.9903734922409058, 0.015129978768527508, 1.0, 0.20811671018600464], interactivity=True, content='Maximize window', source='box_yolo_content_yolo', id=69),
#  ParsedContentResult(type='icon', bbox=[0.5433667898178101, 0.6020526885986328, 0.5527934432029724, 0.6254719495773315], interactivity=True, content='Checkmark', source='box_yolo_content_yolo', id=70),
#  ParsedContentResult(type='icon', bbox=[0.9905775785446167, 0.002051863819360733, 0.999785840511322, 0.022320324555039406], interactivity=True, content='M0,0L9,5 4.5,5z', source='box_yolo_content_yolo', id=71)]

# %%
# from inference.yolo.yolo_ui_icon_merged_inference import Merged_UI_IconBBoxes
# Merged_UI_IconBBoxes.visualise_merged_bboxes_for_paths([image_path], True)

# %%
cluster_model_heirarchy = ClusterModelHeirarchy(os.path.join(omniparser_dir, "sample_cluster_rules.json"))

# %%
cluster_preprocessor = ClusterPreprocessor(parsed_content_results, 
                                            cluster_model_heirarchy, 
                                            omniparser_result_model.omniparser_result)

# %%
# create cluster worker
cluster_worker = ClusterDBSCANWorker(cluster_preprocessor)
# cluster
cluster_results = cluster_worker.cluster()

# print the cluster results
for cluster_result in cluster_results:
    print(cluster_result)
# Out:
# ClusterResult(cluster_result_id='v0_h0', parsed_content_results=[ParsedContentResult(type='icon', bbox=[0.0, 133.0, 262.0, 177.0], interactivity=True, content='Scheduled sessions ', source='box_yolo_content_ocr', id=52), ParsedContentResult(type='icon', bbox=[0.0, 176.0, 263.0, 222.0], interactivity=True, content='Session history ', source='box_yolo_content_ocr', id=53), ParsedContentResult(type='icon', bbox=[0.0, 220.0, 262.0, 266.0], interactivity=True, content='Freelance jobs ', source='box_yolo_content_ocr', id=55), ParsedContentResult(type='icon', bbox=[0.0, 264.0, 260.0, 310.0], interactivity=True, content='Code reviews ', source='box_yolo_content_ocr', id=57)], cluster_bbox_xyxy=[0.0, 133.0, 263.0, 310.0])
# ClusterResult(cluster_result_id='v0_h1', parsed_content_results=[ParsedContentResult(type='text', bbox=[439.0, 206.0, 671.0, 226.0], interactivity=False, content='Project management   Project planning', source='box_ocr_content_ocr', id=6), ParsedContentResult(type='icon', bbox=[346.0, 131.0, 432.0, 153.0], interactivity=True, content='Mive neip ', source='box_yolo_content_ocr', id=66), ParsedContentResult(type='icon', bbox=[345.0, 200.0, 431.0, 223.0], interactivity=True, content='Mive neip ', source='box_yolo_content_ocr', id=71), ParsedContentResult(type='icon', bbox=[345.0, 270.0, 431.0, 293.0], interactivity=True, content='Mive neip ', source='box_yolo_content_ocr', id=74), ParsedContentResult(type='icon', bbox=[436.0, 131.0, 470.0, 151.0], interactivity=True, content='Excel ', source='box_yolo_content_ocr', id=80), ParsedContentResult(type='icon', bbox=[476.0, 130.0, 540.0, 152.0], interactivity=True, content='Excel VBA ', source='box_yolo_content_ocr', id=81), ParsedContentResult(type='icon', bbox=[345.0, 172.0, 596.0, 196.0], interactivity=True, content='Need help with building budget ', source='box_yolo_content_ocr', id=84), ParsedContentResult(type='icon', bbox=[435.0, 270.0, 491.0, 293.0], interactivity=True, content='Linux ', source='box_yolo_content_ocr', id=87), ParsedContentResult(type='icon', bbox=[345.0, 242.0, 618.0, 267.0], interactivity=True, content='Linux and C support for school work ', source='box_yolo_content_ocr', id=93), ParsedContentResult(type='icon', bbox=[287.0, 104.0, 339.0, 152.0], interactivity=True, content="a person's profile or photo.", source='box_yolo_content_yolo', id=102), ParsedContentResult(type='icon', bbox=[286.0, 174.0, 339.0, 221.0], interactivity=True, content="a person's profile or photo.", source='box_yolo_content_yolo', id=103), ParsedContentResult(type='icon', bbox=[437.0, 200.0, 565.0, 221.0], interactivity=True, content='Projection Properties', source='box_yolo_content_yolo', id=108), ParsedContentResult(type='icon', bbox=[288.0, 243.0, 337.0, 293.0], interactivity=True, content='Dictation', source='box_yolo_content_yolo', id=111), ParsedContentResult(type='icon', bbox=[567.0, 200.0, 672.0, 222.0], interactivity=True, content='Projecting', source='box_yolo_content_yolo', id=113)], cluster_bbox_xyxy=[286.0, 104.0, 672.0, 293.0])
# ClusterResult(cluster_result_id='v0_h2', parsed_content_results=[ParsedContentResult(type='text', bbox=[1105.0, 123.0, 1169.0, 137.0], interactivity=False, content='interested', source='box_ocr_content_ocr', id=0), ParsedContentResult(type='text', bbox=[1105.0, 193.0, 1155.0, 207.0], interactivity=False, content='interest', source='box_ocr_content_ocr', id=3), ParsedContentResult(type='text', bbox=[1113.0, 261.0, 1177.0, 277.0], interactivity=False, content='interested', source='box_ocr_content_ocr', id=7)], cluster_bbox_xyxy=[1105.0, 123.0, 1177.0, 277.0])
# ClusterResult(cluster_result_id='v0_h3', parsed_content_results=[ParsedContentResult(type='text', bbox=[1359.0, 123.0, 1453.0, 139.0], interactivity=False, content='29 minutes ag0', source='box_ocr_content_ocr', id=1), ParsedContentResult(type='text', bbox=[1359.0, 193.0, 1451.0, 209.0], interactivity=False, content='40 minutes ag0', source='box_ocr_content_ocr', id=4), ParsedContentResult(type='icon', bbox=[1358.0, 237.0, 1432.0, 299.0], interactivity=True, content='an nour ago ', source='box_yolo_content_ocr', id=77)], cluster_bbox_xyxy=[1358.0, 123.0, 1453.0, 299.0])
# ClusterResult(cluster_result_id='v0_h4', parsed_content_results=[ParsedContentResult(type='text', bbox=[1635.0, 123.0, 1679.0, 139.0], interactivity=False, content='60/hr', source='box_ocr_content_ocr', id=2), ParsedContentResult(type='text', bbox=[1635.0, 193.0, 1679.0, 209.0], interactivity=False, content='60/hr', source='box_ocr_content_ocr', id=5), ParsedContentResult(type='text', bbox=[1635.0, 263.0, 1679.0, 279.0], interactivity=False, content='80/hr', source='box_ocr_content_ocr', id=8)], cluster_bbox_xyxy=[1635.0, 123.0, 1679.0, 279.0])
# ClusterResult(cluster_result_id='v1_h0', parsed_content_results=[ParsedContentResult(type='icon', bbox=[0.0, 308.0, 257.0, 354.0], interactivity=True, content='My posts ', source='box_yolo_content_ocr', id=59), ParsedContentResult(type='icon', bbox=[0.0, 352.0, 255.0, 398.0], interactivity=True, content='Payouts ', source='box_yolo_content_ocr', id=61), ParsedContentResult(type='icon', bbox=[0.0, 396.0, 252.0, 440.0], interactivity=True, content='Settings ', source='box_yolo_content_ocr', id=63)], cluster_bbox_xyxy=[0.0, 308.0, 257.0, 440.0])
# ClusterResult(cluster_result_id='v1_h1', parsed_content_results=[ParsedContentResult(type='text', bbox=[299.0, 323.0, 331.0, 337.0], interactivity=False, content='NEW', source='box_ocr_content_ocr', id=9), ParsedContentResult(type='text', bbox=[342.0, 316.0, 704.0, 344.0], interactivity=False, content='Arc clients are looking for developers like you:', source='box_ocr_content_ocr', id=10), ParsedContentResult(type='text', bbox=[345.0, 349.0, 455.0, 363.0], interactivity=False, content='Find freelance jobs', source='box_ocr_content_ocr', id=11), ParsedContentResult(type='text', bbox=[481.0, 347.0, 649.0, 365.0], interactivity=False, content='pay ranging from $50-580/hr.', source='box_ocr_content_ocr', id=12), ParsedContentResult(type='text', bbox=[345.0, 391.0, 563.0, 411.0], interactivity=False, content='Need help with an Excel task', source='box_ocr_content_ocr', id=13), ParsedContentResult(type='icon', bbox=[346.0, 416.0, 431.0, 437.0], interactivity=True, content='nep KyC ', source='box_yolo_content_ocr', id=72), ParsedContentResult(type='icon', bbox=[436.0, 416.0, 473.0, 437.0], interactivity=True, content='Excel ', source='box_yolo_content_ocr', id=90), ParsedContentResult(type='icon', bbox=[476.0, 415.0, 558.0, 437.0], interactivity=True, content='Data analysis ', source='box_yolo_content_ocr', id=94), ParsedContentResult(type='icon', bbox=[289.0, 387.0, 338.0, 437.0], interactivity=True, content='a person in a suit.', source='box_yolo_content_yolo', id=110)], cluster_bbox_xyxy=[289.0, 316.0, 704.0, 437.0])
# ClusterResult(cluster_result_id='v1_h2', parsed_content_results=[ParsedContentResult(type='text', bbox=[1113.0, 407.0, 1177.0, 421.0], interactivity=False, content='interested', source='box_ocr_content_ocr', id=14)], cluster_bbox_xyxy=[1113.0, 407.0, 1177.0, 421.0])
# ClusterResult(cluster_result_id='v1_h3', parsed_content_results=[ParsedContentResult(type='text', bbox=[1369.0, 407.0, 1431.0, 425.0], interactivity=False, content='hours ag0', source='box_ocr_content_ocr', id=15)], cluster_bbox_xyxy=[1369.0, 407.0, 1431.0, 425.0])
# ClusterResult(cluster_result_id='v1_h4', parsed_content_results=[ParsedContentResult(type='text', bbox=[1633.0, 405.0, 1679.0, 423.0], interactivity=False, content='6o/hr', source='box_ocr_content_ocr', id=16), ParsedContentResult(type='icon', bbox=[1617.0, 319.0, 1755.0, 360.0], interactivity=True, content='Get Started ', source='box_yolo_content_ocr', id=60)], cluster_bbox_xyxy=[1617.0, 319.0, 1755.0, 423.0])
# ClusterResult(cluster_result_id='v2_h0', parsed_content_results=[ParsedContentResult(type='text', bbox=[33.0, 487.0, 127.0, 505.0], interactivity=False, content='Mentor mode', source='box_ocr_content_ocr', id=22), ParsedContentResult(type='icon', bbox=[32.0, 503.0, 218.0, 525.0], interactivity=True, content='Switch to mentee mode ', source='box_yolo_content_ocr', id=75)], cluster_bbox_xyxy=[32.0, 487.0, 218.0, 525.0])
# ClusterResult(cluster_result_id='v2_h1', parsed_content_results=[ParsedContentResult(type='text', bbox=[344.0, 460.0, 436.0, 486.0], interactivity=False, content='Looking for', source='box_ocr_content_ocr', id=17), ParsedContentResult(type='text', bbox=[449.0, 465.0, 785.0, 485.0], interactivity=False, content='tutor to teach me Azure Networking (AZ-700)', source='box_ocr_content_ocr', id=18), ParsedContentResult(type='text', bbox=[475.0, 491.0, 617.0, 507.0], interactivity=False, content='Network administration', source='box_ocr_content_ocr', id=23), ParsedContentResult(type='text', bbox=[345.0, 533.0, 547.0, 553.0], interactivity=False, content='java recap with everything', source='box_ocr_content_ocr', id=24), ParsedContentResult(type='text', bbox=[469.0, 561.0, 517.0, 577.0], interactivity=False, content='Java EE', source='box_ocr_content_ocr', id=28), ParsedContentResult(type='icon', bbox=[346.0, 556.0, 432.0, 578.0], interactivity=True, content='Mive nelp ', source='box_yolo_content_ocr', id=68), ParsedContentResult(type='icon', bbox=[347.0, 485.0, 423.0, 507.0], interactivity=True, content='Long-term ', source='box_yolo_content_ocr', id=70), ParsedContentResult(type='icon', bbox=[435.0, 557.0, 464.0, 577.0], interactivity=True, content='Java ', source='box_yolo_content_ocr', id=91), ParsedContentResult(type='icon', bbox=[429.0, 486.0, 468.0, 507.0], interactivity=True, content='Azure ', source='box_yolo_content_ocr', id=96), ParsedContentResult(type='icon', bbox=[291.0, 529.0, 337.0, 577.0], interactivity=True, content='Text functionality.', source='box_yolo_content_yolo', id=107), ParsedContentResult(type='icon', bbox=[288.0, 455.0, 339.0, 510.0], interactivity=True, content='Gold', source='box_yolo_content_yolo', id=109), ParsedContentResult(type='icon', bbox=[347.0, 527.0, 463.0, 551.0], interactivity=True, content='Save with', source='box_yolo_content_yolo', id=112), ParsedContentResult(type='icon', bbox=[473.0, 486.0, 527.0, 507.0], interactivity=True, content='Network', source='box_yolo_content_yolo', id=114), ParsedContentResult(type='icon', bbox=[464.0, 527.0, 547.0, 552.0], interactivity=True, content='Everything', source='box_yolo_content_yolo', id=115)], cluster_bbox_xyxy=[288.0, 455.0, 785.0, 578.0])
# ClusterResult(cluster_result_id='v2_h2', parsed_content_results=[ParsedContentResult(type='text', bbox=[1105.0, 477.0, 1155.0, 491.0], interactivity=False, content='interest', source='box_ocr_content_ocr', id=19), ParsedContentResult(type='text', bbox=[1113.0, 547.0, 1175.0, 561.0], interactivity=False, content='interested', source='box_ocr_content_ocr', id=25)], cluster_bbox_xyxy=[1105.0, 477.0, 1175.0, 561.0])
# ClusterResult(cluster_result_id='v2_h3', parsed_content_results=[ParsedContentResult(type='text', bbox=[1369.0, 477.0, 1431.0, 493.0], interactivity=False, content='hours 2g0', source='box_ocr_content_ocr', id=20), ParsedContentResult(type='text', bbox=[1369.0, 547.0, 1431.0, 565.0], interactivity=False, content='hours ag0', source='box_ocr_content_ocr', id=26)], cluster_bbox_xyxy=[1369.0, 477.0, 1431.0, 565.0])
# ClusterResult(cluster_result_id='v2_h4', parsed_content_results=[ParsedContentResult(type='text', bbox=[1635.0, 477.0, 1679.0, 493.0], interactivity=False, content='60/hr', source='box_ocr_content_ocr', id=21), ParsedContentResult(type='text', bbox=[1633.0, 545.0, 1679.0, 563.0], interactivity=False, content='6o/hr', source='box_ocr_content_ocr', id=27)], cluster_bbox_xyxy=[1633.0, 477.0, 1679.0, 563.0])
# ClusterResult(cluster_result_id='v3_h0', parsed_content_results=[ParsedContentResult(type='text', bbox=[346.0, 599.0, 668.0, 626.0], interactivity=False, content='Need help fixing decaying rewards from RL', source='box_ocr_content_ocr', id=29), ParsedContentResult(type='text', bbox=[439.0, 633.0, 465.0, 647.0], interactivity=False, content='Ct+', source='box_ocr_content_ocr', id=33), ParsedContentResult(type='text', bbox=[471.0, 631.0, 651.0, 649.0], interactivity=False, content='Deep Reinforcement Learning', source='box_ocr_content_ocr', id=34), ParsedContentResult(type='icon', bbox=[346.0, 626.0, 431.0, 649.0], interactivity=True, content='Mive nelp ', source='box_yolo_content_ocr', id=88), ParsedContentResult(type='icon', bbox=[290.0, 600.0, 337.0, 646.0], interactivity=True, content='Crop', source='box_yolo_content_yolo', id=105)], cluster_bbox_xyxy=[290.0, 599.0, 668.0, 649.0])
# ClusterResult(cluster_result_id='v3_h1', parsed_content_results=[ParsedContentResult(type='icon', bbox=[710.0, 625.0, 797.0, 647.0], interactivity=True, content='Transtormers ', source='box_yolo_content_ocr', id=82), ParsedContentResult(type='icon', bbox=[652.0, 625.0, 709.0, 648.0], interactivity=True, content='PyTorch ', source='box_yolo_content_ocr', id=95)], cluster_bbox_xyxy=[652.0, 625.0, 797.0, 648.0])
# ClusterResult(cluster_result_id='v3_h2', parsed_content_results=[ParsedContentResult(type='text', bbox=[1105.0, 617.0, 1169.0, 633.0], interactivity=False, content='interested', source='box_ocr_content_ocr', id=30)], cluster_bbox_xyxy=[1105.0, 617.0, 1169.0, 633.0])
# ClusterResult(cluster_result_id='v3_h3', parsed_content_results=[ParsedContentResult(type='text', bbox=[1369.0, 617.0, 1431.0, 635.0], interactivity=False, content='hours ag0', source='box_ocr_content_ocr', id=31)], cluster_bbox_xyxy=[1369.0, 617.0, 1431.0, 635.0])
# ClusterResult(cluster_result_id='v3_h4', parsed_content_results=[ParsedContentResult(type='text', bbox=[1635.0, 617.0, 1679.0, 633.0], interactivity=False, content='80/hr', source='box_ocr_content_ocr', id=32)], cluster_bbox_xyxy=[1635.0, 617.0, 1679.0, 633.0])
# ClusterResult(cluster_result_id='v4_h0', parsed_content_results=[ParsedContentResult(type='text', bbox=[354.0, 670.0, 854.0, 698.0], interactivity=False, content='need help for upgrade my react native application to latest version', source='box_ocr_content_ocr', id=35), ParsedContentResult(type='text', bbox=[537.0, 703.0, 615.0, 717.0], interactivity=False, content='React Native', source='box_ocr_content_ocr', id=39), ParsedContentResult(type='icon', bbox=[346.0, 695.0, 432.0, 719.0], interactivity=True, content='Mive nelp ', source='box_yolo_content_ocr', id=76), ParsedContentResult(type='icon', bbox=[434.0, 696.0, 535.0, 717.0], interactivity=True, content='Version control ', source='box_yolo_content_ocr', id=85), ParsedContentResult(type='icon', bbox=[291.0, 669.0, 337.0, 717.0], interactivity=True, content='uBlock Origin (Ctrl+Shift+F)', source='box_yolo_content_yolo', id=104)], cluster_bbox_xyxy=[291.0, 669.0, 854.0, 719.0])
# ClusterResult(cluster_result_id='v4_h1', parsed_content_results=[ParsedContentResult(type='text', bbox=[1111.0, 687.0, 1175.0, 701.0], interactivity=False, content='interested', source='box_ocr_content_ocr', id=36)], cluster_bbox_xyxy=[1111.0, 687.0, 1175.0, 701.0])
# ClusterResult(cluster_result_id='v4_h2', parsed_content_results=[ParsedContentResult(type='text', bbox=[1369.0, 687.0, 1431.0, 705.0], interactivity=False, content='hours ag0', source='box_ocr_content_ocr', id=37)], cluster_bbox_xyxy=[1369.0, 687.0, 1431.0, 705.0])
# ClusterResult(cluster_result_id='v4_h3', parsed_content_results=[ParsedContentResult(type='text', bbox=[1635.0, 687.0, 1679.0, 703.0], interactivity=False, content='60/hr', source='box_ocr_content_ocr', id=38)], cluster_bbox_xyxy=[1635.0, 687.0, 1679.0, 703.0])
# ClusterResult(cluster_result_id='v5_h0', parsed_content_results=[ParsedContentResult(type='text', bbox=[344.0, 738.0, 772.0, 766.0], interactivity=False, content='GCP google cloud High availability and Disaster Recovery', source='box_ocr_content_ocr', id=40), ParsedContentResult(type='icon', bbox=[435.0, 765.0, 578.0, 788.0], interactivity=True, content='Google Cloud Platform ', source='box_yolo_content_ocr', id=69), ParsedContentResult(type='icon', bbox=[347.0, 767.0, 432.0, 788.0], interactivity=True, content='Mive nelp ', source='box_yolo_content_ocr', id=78), ParsedContentResult(type='icon', bbox=[581.0, 765.0, 742.0, 787.0], interactivity=True, content='Disaster recovery planning ', source='box_yolo_content_ocr', id=79), ParsedContentResult(type='icon', bbox=[292.0, 739.0, 337.0, 787.0], interactivity=True, content='Facebook.', source='box_yolo_content_yolo', id=106)], cluster_bbox_xyxy=[292.0, 738.0, 772.0, 788.0])
# ClusterResult(cluster_result_id='v5_h1', parsed_content_results=[ParsedContentResult(type='icon', bbox=[744.0, 765.0, 864.0, 787.0], interactivity=True, content='Cloud Architecture ', source='box_yolo_content_ocr', id=86)], cluster_bbox_xyxy=[744.0, 765.0, 864.0, 787.0])
# ClusterResult(cluster_result_id='v5_h2', parsed_content_results=[ParsedContentResult(type='text', bbox=[1105.0, 757.0, 1169.0, 771.0], interactivity=False, content='interested', source='box_ocr_content_ocr', id=41)], cluster_bbox_xyxy=[1105.0, 757.0, 1169.0, 771.0])
# ClusterResult(cluster_result_id='v5_h3', parsed_content_results=[ParsedContentResult(type='text', bbox=[1369.0, 757.0, 1431.0, 775.0], interactivity=False, content='hours ag0', source='box_ocr_content_ocr', id=42)], cluster_bbox_xyxy=[1369.0, 757.0, 1431.0, 775.0])
# ClusterResult(cluster_result_id='v5_h4', parsed_content_results=[ParsedContentResult(type='text', bbox=[1635.0, 757.0, 1679.0, 773.0], interactivity=False, content='80/hr', source='box_ocr_content_ocr', id=43)], cluster_bbox_xyxy=[1635.0, 757.0, 1679.0, 773.0])
# ClusterResult(cluster_result_id='v6_h0', parsed_content_results=[ParsedContentResult(type='text', bbox=[437.0, 843.0, 465.0, 857.0], interactivity=False, content='Ct+', source='box_ocr_content_ocr', id=47), ParsedContentResult(type='icon', bbox=[469.0, 835.0, 555.0, 857.0], interactivity=True, content='Programming ', source='box_yolo_content_ocr', id=83), ParsedContentResult(type='icon', bbox=[347.0, 836.0, 431.0, 857.0], interactivity=True, content='Mive nelp ', source='box_yolo_content_ocr', id=89), ParsedContentResult(type='icon', bbox=[345.0, 807.0, 782.0, 832.0], interactivity=True, content="have a ' large project am looking for help with debugging ", source='box_yolo_content_ocr', id=92), ParsedContentResult(type='icon', bbox=[286.0, 807.0, 338.0, 857.0], interactivity=True, content='Refresh or reload the page.', source='box_yolo_content_yolo', id=100)], cluster_bbox_xyxy=[286.0, 807.0, 782.0, 857.0])
# ClusterResult(cluster_result_id='v6_h1', parsed_content_results=[ParsedContentResult(type='text', bbox=[1113.0, 827.0, 1175.0, 841.0], interactivity=False, content='interested', source='box_ocr_content_ocr', id=44)], cluster_bbox_xyxy=[1113.0, 827.0, 1175.0, 841.0])
# ClusterResult(cluster_result_id='v6_h2', parsed_content_results=[ParsedContentResult(type='text', bbox=[1369.0, 827.0, 1431.0, 845.0], interactivity=False, content='hours ag0', source='box_ocr_content_ocr', id=45)], cluster_bbox_xyxy=[1369.0, 827.0, 1431.0, 845.0])
# ClusterResult(cluster_result_id='v6_h3', parsed_content_results=[ParsedContentResult(type='text', bbox=[1633.0, 825.0, 1679.0, 843.0], interactivity=False, content='8o/hr', source='box_ocr_content_ocr', id=46)], cluster_bbox_xyxy=[1633.0, 825.0, 1679.0, 843.0])
# ClusterResult(cluster_result_id='v7_h0', parsed_content_results=[ParsedContentResult(type='text', bbox=[0.0, 892.0, 26.0, 898.0], interactivity=False, content='Knn', source='box_ocr_content_ocr', id=48)], cluster_bbox_xyxy=[0.0, 892.0, 26.0, 898.0])
# ClusterResult(cluster_result_id='v7_h1', parsed_content_results=[ParsedContentResult(type='text', bbox=[64.0, 892.0, 130.0, 898.0], interactivity=False, content='NEnteme', source='box_ocr_content_ocr', id=49)], cluster_bbox_xyxy=[64.0, 892.0, 130.0, 898.0])
# ClusterResult(cluster_result_id='v7_h2', parsed_content_results=[ParsedContentResult(type='text', bbox=[345.0, 881.0, 647.0, 898.0], interactivity=False, content='Enable debug logging for IMaaS Pipeline', source='box_ocr_content_ocr', id=50)], cluster_bbox_xyxy=[345.0, 881.0, 647.0, 898.0])
# ClusterResult(cluster_result_id='v7_h3', parsed_content_results=[ParsedContentResult(type='text', bbox=[1639.0, 881.0, 1677.0, 898.0], interactivity=False, content='chat', source='box_ocr_content_ocr', id=51)], cluster_bbox_xyxy=[1639.0, 881.0, 1677.0, 898.0])

# %%
base64_image_str, np_image = cluster_worker.get_visualisation_for_cluster_results()
# display the cluster visualization numpy array
type(base64_image_str)
plot_numpy_image(np_image)
